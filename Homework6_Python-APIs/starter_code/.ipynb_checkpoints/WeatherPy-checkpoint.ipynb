# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time


# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 625

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# OpenWeatherMap API Key
api_key = "61865aa8640807626e4e6c13a681b72d"

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + urllib.request.pathname2url(city)

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    print(city_url)

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | aswan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=aswan
# Processing Record 2 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=punta%20arenas
# Processing Record 3 of Set 1 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=grand%20river%20south%20east
# City not found. Skipping...
# Processing Record 4 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=mataura
# Processing Record 5 of Set 1 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=georgetown
# Processing Record 6 of Set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=hobart
# Processing Record 7 of Set 1 | khuzdar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=khuzdar
# Processing Record 8 of Set 1 | springbok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=springbok
# Processing Record 9 of Set 1 | umm lajj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=umm%20lajj
# Processing Record 10 of Set 1 | lokosovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=lokosovo
# Processing Record 11 of Set 1 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=kruisfontein
# Processing Record 12 of Set 1 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=port%20elizabeth
# Processing Record 13 of Set 1 | ozgon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=ozgon
# City not found. Skipping...
# Processing Record 14 of Set 1 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=cap%20malheureux
# Processing Record 15 of Set 1 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=mys%20shmidta
# City not found. Skipping...
# Processing Record 16 of Set 1 | plettenberg bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=plettenberg%20bay
# Processing Record 17 of Set 1 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=longyearbyen
# Processing Record 18 of Set 1 | sambava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=sambava
# Processing Record 19 of Set 1 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=bengkulu
# City not found. Skipping...
# Processing Record 20 of Set 1 | port blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=port%20blair
# Processing Record 21 of Set 1 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=new%20norfolk
# Processing Record 22 of Set 1 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=clyde%20river
# Processing Record 23 of Set 1 | riyadh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=riyadh
# Processing Record 24 of Set 1 | beisfjord
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=beisfjord
# Processing Record 25 of Set 1 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=puerto%20ayora
# Processing Record 26 of Set 1 | notre-dame-du-lac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=notre-dame-du-lac
# Processing Record 27 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=ushuaia
# Processing Record 28 of Set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=bredasdorp
# Processing Record 29 of Set 1 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=fortuna
# Processing Record 30 of Set 1 | padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=padang
# Processing Record 31 of Set 1 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=esperance
# Processing Record 32 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=vaini
# Processing Record 33 of Set 1 | mareeba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=mareeba
# Processing Record 34 of Set 1 | lom sak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=lom%20sak
# Processing Record 35 of Set 1 | milan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=milan
# Processing Record 36 of Set 1 | zhangjiakou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=zhangjiakou
# Processing Record 37 of Set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=kapaa
# Processing Record 38 of Set 1 | mayskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=mayskiy
# Processing Record 39 of Set 1 | wahran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=wahran
# City not found. Skipping...
# Processing Record 40 of Set 1 | temaraia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=temaraia
# City not found. Skipping...
# Processing Record 41 of Set 1 | lakes entrance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=lakes%20entrance
# Processing Record 42 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=albany
# Processing Record 43 of Set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=atuona
# Processing Record 44 of Set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=jamestown
# Processing Record 45 of Set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=barrow
# Processing Record 46 of Set 1 | makakilo city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=makakilo%20city
# Processing Record 47 of Set 1 | trincomalee
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=trincomalee
# Processing Record 48 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=rikitea
# Processing Record 49 of Set 1 | hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=hualmay
# Processing Record 50 of Set 1 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=khatanga
# Processing Record 0 of Set 2 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 2 | izazi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=izazi
# Processing Record 2 of Set 2 | grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=grindavik
# Processing Record 3 of Set 2 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=lebu
# Processing Record 4 of Set 2 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=bluff
# Processing Record 5 of Set 2 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=qaanaaq
# Processing Record 6 of Set 2 | georgiyevka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=georgiyevka
# Processing Record 7 of Set 2 | pontianak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=pontianak
# Processing Record 8 of Set 2 | mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=mayo
# Processing Record 9 of Set 2 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=tuktoyaktuk
# Processing Record 10 of Set 2 | pereslavl-zalesskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=pereslavl-zalesskiy
# Processing Record 11 of Set 2 | okha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=okha
# Processing Record 12 of Set 2 | jujuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=jujuy
# City not found. Skipping...
# Processing Record 13 of Set 2 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=avarua
# Processing Record 14 of Set 2 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=tasiilaq
# Processing Record 15 of Set 2 | minudasht
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=minudasht
# Processing Record 16 of Set 2 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=pisco
# Processing Record 17 of Set 2 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=komsomolskiy
# Processing Record 18 of Set 2 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=hermanus
# Processing Record 19 of Set 2 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=castro
# Processing Record 20 of Set 2 | asyut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=asyut
# Processing Record 21 of Set 2 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=hithadhoo
# Processing Record 22 of Set 2 | barra de sao francisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=barra%20de%20sao%20francisco
# Processing Record 23 of Set 2 | yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=yulara
# Processing Record 24 of Set 2 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=busselton
# Processing Record 25 of Set 2 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=port%20alfred
# Processing Record 26 of Set 2 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=quatre%20cocos
# Processing Record 27 of Set 2 | alotau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=alotau
# City not found. Skipping...
# Processing Record 28 of Set 2 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=mount%20gambier
# Processing Record 29 of Set 2 | tobolsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=tobolsk
# Processing Record 30 of Set 2 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=dikson
# Processing Record 31 of Set 2 | payakumbuh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=payakumbuh
# Processing Record 32 of Set 2 | sibu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=sibu
# Processing Record 33 of Set 2 | hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=hami
# Processing Record 34 of Set 2 | umm kaddadah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=umm%20kaddadah
# Processing Record 35 of Set 2 | levelland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=levelland
# Processing Record 36 of Set 2 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=thompson
# Processing Record 37 of Set 2 | fevralsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=fevralsk
# City not found. Skipping...
# Processing Record 38 of Set 2 | dhidhdhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=dhidhdhoo
# Processing Record 39 of Set 2 | potgietersrus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=potgietersrus
# City not found. Skipping...
# Processing Record 40 of Set 2 | waipawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=waipawa
# Processing Record 41 of Set 2 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=norman%20wells
# Processing Record 42 of Set 2 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 2 | samarai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=samarai
# Processing Record 44 of Set 2 | hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=hobyo
# Processing Record 45 of Set 2 | rungata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=rungata
# City not found. Skipping...
# Processing Record 46 of Set 2 | palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=palmer
# Processing Record 47 of Set 2 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=olafsvik
# City not found. Skipping...
# Processing Record 48 of Set 2 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=mahebourg
# Processing Record 49 of Set 2 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=illoqqortoormiut
# City not found. Skipping...
# Processing Record 0 of Set 3 | aktash
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=aktash
# City not found. Skipping...
# Processing Record 1 of Set 3 | bonavista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=bonavista
# Processing Record 2 of Set 3 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=saint-augustin
# Processing Record 3 of Set 3 | loandjili
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=loandjili
# Processing Record 4 of Set 3 | islahiye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=islahiye
# Processing Record 5 of Set 3 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=tiksi
# Processing Record 6 of Set 3 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=yellowknife
# Processing Record 7 of Set 3 | tucurui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=tucurui
# Processing Record 8 of Set 3 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=port%20lincoln
# Processing Record 9 of Set 3 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=arraial%20do%20cabo
# Processing Record 10 of Set 3 | conceicao da barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=conceicao%20da%20barra
# Processing Record 11 of Set 3 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 3 | naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=naze
# Processing Record 13 of Set 3 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=belushya%20guba
# City not found. Skipping...
# Processing Record 14 of Set 3 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=bethel
# Processing Record 15 of Set 3 | mananara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=mananara
# City not found. Skipping...
# Processing Record 16 of Set 3 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=pevek
# Processing Record 17 of Set 3 | xining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=xining
# Processing Record 18 of Set 3 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=provideniya
# Processing Record 19 of Set 3 | griffith
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=griffith
# Processing Record 20 of Set 3 | port hedland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=port%20hedland
# Processing Record 21 of Set 3 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=alofi
# Processing Record 22 of Set 3 | mocuba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=mocuba
# Processing Record 23 of Set 3 | tianguismanalco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=tianguismanalco
# Processing Record 24 of Set 3 | hervey bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=hervey%20bay
# Processing Record 25 of Set 3 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=chokurdakh
# Processing Record 26 of Set 3 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=hasaki
# Processing Record 27 of Set 3 | porto novo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=porto%20novo
# Processing Record 28 of Set 3 | puerto del rosario
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=puerto%20del%20rosario
# Processing Record 29 of Set 3 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=pangnirtung
# Processing Record 30 of Set 3 | babanusah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=babanusah
# City not found. Skipping...
# Processing Record 31 of Set 3 | asau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=asau
# City not found. Skipping...
# Processing Record 32 of Set 3 | sovetskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=sovetskiy
# Processing Record 33 of Set 3 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=saint-philippe
# Processing Record 34 of Set 3 | uribia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=uribia
# Processing Record 35 of Set 3 | thunder bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=thunder%20bay
# Processing Record 36 of Set 3 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=faanui
# Processing Record 37 of Set 3 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=butaritari
# Processing Record 38 of Set 3 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=lorengau
# Processing Record 39 of Set 3 | kapit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=kapit
# Processing Record 40 of Set 3 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=carnarvon
# Processing Record 41 of Set 3 | narovchat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=narovchat
# Processing Record 42 of Set 3 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=cabo%20san%20lucas
# Processing Record 43 of Set 3 | cape elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=cape%20elizabeth
# City not found. Skipping...
# Processing Record 44 of Set 3 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=okhotsk
# Processing Record 45 of Set 3 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=talnakh
# Processing Record 46 of Set 3 | bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=bubaque
# Processing Record 47 of Set 3 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=coquimbo
# Processing Record 48 of Set 3 | yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=yerbogachen
# Processing Record 49 of Set 3 | amderma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=amderma
# City not found. Skipping...
# Processing Record 0 of Set 4 | buchanan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=buchanan
# Processing Record 1 of Set 4 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=upernavik
# Processing Record 2 of Set 4 | kenai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=kenai
# Processing Record 3 of Set 4 | turukhansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=turukhansk
# Processing Record 4 of Set 4 | kalamare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=kalamare
# Processing Record 5 of Set 4 | daru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=daru
# Processing Record 6 of Set 4 | shelburne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=shelburne
# Processing Record 7 of Set 4 | la paz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=la%20paz
# Processing Record 8 of Set 4 | ocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=ocos
# Processing Record 9 of Set 4 | luangwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=luangwa
# Processing Record 10 of Set 4 | port macquarie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=port%20macquarie
# Processing Record 11 of Set 4 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=ponta%20do%20sol
# Processing Record 12 of Set 4 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=east%20london
# Processing Record 13 of Set 4 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=katsuura
# Processing Record 14 of Set 4 | berbera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=berbera
# City not found. Skipping...
# Processing Record 15 of Set 4 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=bambous%20virieux
# Processing Record 16 of Set 4 | stornoway
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=stornoway
# City not found. Skipping...
# Processing Record 17 of Set 4 | lar gerd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=lar%20gerd
# City not found. Skipping...
# Processing Record 18 of Set 4 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=ancud
# Processing Record 19 of Set 4 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=saskylakh
# Processing Record 20 of Set 4 | flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=flinders
# Processing Record 21 of Set 4 | sarandi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=sarandi
# Processing Record 22 of Set 4 | pochutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=pochutla
# Processing Record 23 of Set 4 | torrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=torrington
# Processing Record 24 of Set 4 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 4 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=cape%20town
# Processing Record 26 of Set 4 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=ostrovnoy
# Processing Record 27 of Set 4 | burnie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=burnie
# Processing Record 28 of Set 4 | sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=sola
# Processing Record 29 of Set 4 | rasht
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=rasht
# Processing Record 30 of Set 4 | emborion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=emborion
# Processing Record 31 of Set 4 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=lagoa
# Processing Record 32 of Set 4 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=lompoc
# Processing Record 33 of Set 4 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=torbay
# Processing Record 34 of Set 4 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=sinnamary
# Processing Record 35 of Set 4 | kitangari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=kitangari
# Processing Record 36 of Set 4 | gold coast
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=gold%20coast
# Processing Record 37 of Set 4 | huarmey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=huarmey
# Processing Record 38 of Set 4 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=victoria
# Processing Record 39 of Set 4 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=chuy
# Processing Record 40 of Set 4 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=meulaboh
# Processing Record 41 of Set 4 | rohnert park
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=rohnert%20park
# Processing Record 42 of Set 4 | honiara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=honiara
# Processing Record 43 of Set 4 | hay river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=hay%20river
# Processing Record 44 of Set 4 | petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=petropavlovsk-kamchatskiy
# Processing Record 45 of Set 4 | shubarshi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=shubarshi
# Processing Record 46 of Set 4 | warqla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=warqla
# City not found. Skipping...
# Processing Record 47 of Set 4 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=codrington
# Processing Record 48 of Set 4 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=saint%20george
# Processing Record 49 of Set 4 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=tumannyy
# City not found. Skipping...
# Processing Record 0 of Set 5 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=hilo
# Processing Record 1 of Set 5 | awash
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=awash
# Processing Record 2 of Set 5 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=nanortalik
# Processing Record 3 of Set 5 | sestri levante
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=sestri%20levante
# Processing Record 4 of Set 5 | warin chamrap
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=warin%20chamrap
# Processing Record 5 of Set 5 | baykit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=baykit
# Processing Record 6 of Set 5 | caramay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=caramay
# Processing Record 7 of Set 5 | thomaston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=thomaston
# Processing Record 8 of Set 5 | the valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=the%20valley
# Processing Record 9 of Set 5 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=klaksvik
# Processing Record 10 of Set 5 | puerto escondido
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=puerto%20escondido
# Processing Record 11 of Set 5 | biloxi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=biloxi
# Processing Record 12 of Set 5 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=ribeira%20grande
# Processing Record 13 of Set 5 | saleaula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=saleaula
# City not found. Skipping...
# Processing Record 14 of Set 5 | paragominas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=paragominas
# Processing Record 15 of Set 5 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 5 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=leningradskiy
# Processing Record 17 of Set 5 | krasnoufimsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=krasnoufimsk
# Processing Record 18 of Set 5 | orgun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=orgun
# City not found. Skipping...
# Processing Record 19 of Set 5 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=tuatapere
# Processing Record 20 of Set 5 | juba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=juba
# Processing Record 21 of Set 5 | champerico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=champerico
# Processing Record 22 of Set 5 | tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=tura
# Processing Record 23 of Set 5 | chapais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=chapais
# Processing Record 24 of Set 5 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 5 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=nouadhibou
# Processing Record 26 of Set 5 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=kahului
# Processing Record 27 of Set 5 | dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=dunedin
# Processing Record 28 of Set 5 | almaznyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=almaznyy
# Processing Record 29 of Set 5 | kismayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=kismayo
# City not found. Skipping...
# Processing Record 30 of Set 5 | pathein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=pathein
# Processing Record 31 of Set 5 | silver city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=silver%20city
# Processing Record 32 of Set 5 | derbent
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=derbent
# Processing Record 33 of Set 5 | lazaro cardenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=lazaro%20cardenas
# Processing Record 34 of Set 5 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=vila%20franca%20do%20campo
# Processing Record 35 of Set 5 | manggar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=manggar
# Processing Record 36 of Set 5 | haibowan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=haibowan
# City not found. Skipping...
# Processing Record 37 of Set 5 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=yar-sale
# Processing Record 38 of Set 5 | mattru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=mattru
# Processing Record 39 of Set 5 | zhangye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=zhangye
# Processing Record 40 of Set 5 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=kodiak
# Processing Record 41 of Set 5 | fort abbas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=fort%20abbas
# Processing Record 42 of Set 5 | monteria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=monteria
# Processing Record 43 of Set 5 | richards bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=richards%20bay
# Processing Record 44 of Set 5 | namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=namatanai
# Processing Record 45 of Set 5 | louisbourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 5 | agudos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=agudos
# Processing Record 47 of Set 5 | amarwara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=amarwara
# Processing Record 48 of Set 5 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=nikolskoye
# Processing Record 49 of Set 5 | gamboula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=gamboula
# Processing Record 0 of Set 6 | colares
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=colares
# Processing Record 1 of Set 6 | vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=vao
# Processing Record 2 of Set 6 | sawakin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=sawakin
# Processing Record 3 of Set 6 | southbridge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=southbridge
# Processing Record 4 of Set 6 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=iqaluit
# Processing Record 5 of Set 6 | gerzat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=gerzat
# Processing Record 6 of Set 6 | boa vista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=boa%20vista
# Processing Record 7 of Set 6 | mantua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=mantua
# Processing Record 8 of Set 6 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=vardo
# Processing Record 9 of Set 6 | chimbote
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=chimbote
# Processing Record 10 of Set 6 | narrabri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=narrabri
# Processing Record 11 of Set 6 | bodden town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=bodden%20town
# Processing Record 12 of Set 6 | novyy urengoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=novyy%20urengoy
# Processing Record 13 of Set 6 | vaitape
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=vaitape
# Processing Record 14 of Set 6 | frontera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=frontera
# Processing Record 15 of Set 6 | isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=isangel
# Processing Record 16 of Set 6 | tezu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=tezu
# Processing Record 17 of Set 6 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=touros
# Processing Record 18 of Set 6 | samusu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=samusu
# City not found. Skipping...
# Processing Record 19 of Set 6 | lulea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=lulea
# Processing Record 20 of Set 6 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=sitka
# Processing Record 21 of Set 6 | bozeman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=bozeman
# Processing Record 22 of Set 6 | vila velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=vila%20velha
# Processing Record 23 of Set 6 | gazanjyk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=gazanjyk
# Processing Record 24 of Set 6 | marcona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=marcona
# City not found. Skipping...
# Processing Record 25 of Set 6 | ranong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=ranong
# Processing Record 26 of Set 6 | santa isabel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=santa%20isabel
# Processing Record 27 of Set 6 | muisne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=muisne
# Processing Record 28 of Set 6 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=sao%20filipe
# Processing Record 29 of Set 6 | dover
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=dover
# Processing Record 30 of Set 6 | diamantino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=diamantino
# Processing Record 31 of Set 6 | rawannawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=rawannawi
# City not found. Skipping...
# Processing Record 32 of Set 6 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=aklavik
# Processing Record 33 of Set 6 | whyalla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=whyalla
# Processing Record 34 of Set 6 | yatou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=yatou
# Processing Record 35 of Set 6 | flagstaff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=flagstaff
# Processing Record 36 of Set 6 | muzhi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=muzhi
# Processing Record 37 of Set 6 | nam dinh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=nam%20dinh
# Processing Record 38 of Set 6 | gamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=gamba
# Processing Record 39 of Set 6 | skibbereen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=skibbereen
# Processing Record 40 of Set 6 | mezhdurechenskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=mezhdurechenskiy
# Processing Record 41 of Set 6 | halalo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=halalo
# City not found. Skipping...
# Processing Record 42 of Set 6 | kandrian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=kandrian
# Processing Record 43 of Set 6 | nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=nome
# Processing Record 44 of Set 6 | lardos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=lardos
# Processing Record 45 of Set 6 | lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=lata
# Processing Record 46 of Set 6 | soyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=soyo
# Processing Record 47 of Set 6 | shaoyang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=shaoyang
# Processing Record 48 of Set 6 | victor harbor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=victor%20harbor
# Processing Record 49 of Set 6 | suileng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=suileng
# Processing Record 0 of Set 7 | ust-kan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=ust-kan
# Processing Record 1 of Set 7 | broken hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=broken%20hill
# Processing Record 2 of Set 7 | ust-kulom
# ...
# Processing Record 24 of Set 11 | sinkat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=sinkat
# City not found. Skipping...
# Processing Record 25 of Set 11 | goma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=goma
# Processing Record 26 of Set 11 | aykhal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=aykhal
# Processing Record 27 of Set 11 | yarada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=yarada
# Processing Record 28 of Set 11 | valparaiso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=valparaiso
# Processing Record 29 of Set 11 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=sao%20joao%20da%20barra
# Processing Record 30 of Set 11 | monte patria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=monte%20patria
# Processing Record 31 of Set 11 | ust-tsilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=ust-tsilma
# Processing Record 32 of Set 11 | berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=berlevag
# Processing Record 33 of Set 11 | ayni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=ayni
# Processing Record 34 of Set 11 | kota kinabalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=kota%20kinabalu
# Processing Record 35 of Set 11 | talara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=talara
# Processing Record 36 of Set 11 | simbahan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=simbahan
# Processing Record 37 of Set 11 | mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=mitsamiouli
# Processing Record 38 of Set 11 | kualakapuas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=kualakapuas
# Processing Record 39 of Set 11 | guantanamo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=guantanamo
# Processing Record 40 of Set 11 | yomitan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=yomitan
# City not found. Skipping...
# Processing Record 41 of Set 11 | ouallam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=ouallam
# Processing Record 42 of Set 11 | colquechaca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=colquechaca
# Processing Record 43 of Set 11 | zaoyang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=zaoyang
# Processing Record 44 of Set 11 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=ixtapa
# Processing Record 45 of Set 11 | solnechnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=solnechnyy
# Processing Record 46 of Set 11 | sretensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=sretensk
# Processing Record 47 of Set 11 | san rafael
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=san%20rafael
# Processing Record 48 of Set 11 | porto santo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=porto%20santo
# City not found. Skipping...
# Processing Record 49 of Set 11 | antalaha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=antalaha
# Processing Record 0 of Set 12 | kiama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=kiama
# Processing Record 1 of Set 12 | nyurba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=nyurba
# Processing Record 2 of Set 12 | izhma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=izhma
# Processing Record 3 of Set 12 | adeje
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=adeje
# Processing Record 4 of Set 12 | mecca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=mecca
# Processing Record 5 of Set 12 | maldonado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=maldonado
# Processing Record 6 of Set 12 | tchibanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=tchibanga
# Processing Record 7 of Set 12 | nishihara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=nishihara
# Processing Record 8 of Set 12 | sokoni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=sokoni
# Processing Record 9 of Set 12 | bolungarvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=bolungarvik
# City not found. Skipping...
# Processing Record 10 of Set 12 | tadine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=tadine
# Processing Record 11 of Set 12 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=tilichiki
# Processing Record 12 of Set 12 | port hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=port%20hardy
# Processing Record 13 of Set 12 | baymak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=baymak
# Processing Record 14 of Set 12 | gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=gat
# Processing Record 15 of Set 12 | kolosovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=kolosovka
# Processing Record 16 of Set 12 | isla del bosque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=isla%20del%20bosque
# Processing Record 17 of Set 12 | palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 12 | maningrida
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=maningrida
# Processing Record 19 of Set 12 | hirado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=hirado
# Processing Record 20 of Set 12 | morondava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=morondava
# Processing Record 21 of Set 12 | luanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=luanda
# Processing Record 22 of Set 12 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=narsaq
# Processing Record 23 of Set 12 | vizinga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=vizinga
# Processing Record 24 of Set 12 | panguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=panguna
# Processing Record 25 of Set 12 | boca do acre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=boca%20do%20acre
# Processing Record 26 of Set 12 | coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=coihaique
# Processing Record 27 of Set 12 | monrovia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=monrovia
# Processing Record 28 of Set 12 | havoysund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=havoysund
# Processing Record 29 of Set 12 | dubenskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=dubenskiy
# City not found. Skipping...
# Processing Record 30 of Set 12 | natal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=natal
# Processing Record 31 of Set 12 | bassano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=bassano
# Processing Record 32 of Set 12 | ayr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=ayr
# Processing Record 33 of Set 12 | izyum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=izyum
# Processing Record 34 of Set 12 | wanning
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=wanning
# Processing Record 35 of Set 12 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=geraldton
# Processing Record 36 of Set 12 | hangha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=hangha
# Processing Record 37 of Set 12 | roald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=roald
# Processing Record 38 of Set 12 | mbuji-mayi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=mbuji-mayi
# Processing Record 39 of Set 12 | eresos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=eresos
# Processing Record 40 of Set 12 | manakara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=manakara
# Processing Record 41 of Set 12 | lakatoro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=lakatoro
# Processing Record 42 of Set 12 | cooma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=cooma
# Processing Record 43 of Set 12 | korla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=korla
# City not found. Skipping...
# Processing Record 44 of Set 12 | kargasok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=kargasok
# Processing Record 45 of Set 12 | margraten
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=margraten
# Processing Record 46 of Set 12 | sao gabriel da cachoeira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=sao%20gabriel%20da%20cachoeira
# Processing Record 47 of Set 12 | chagda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=chagda
# City not found. Skipping...
# Processing Record 48 of Set 12 | abu dhabi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=abu%20dhabi
# Processing Record 49 of Set 12 | boende
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=boende
# Processing Record 0 of Set 13 | govardhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=govardhan
# Processing Record 1 of Set 13 | tortoli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=tortoli
# Processing Record 2 of Set 13 | esqueda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=esqueda
# Processing Record 3 of Set 13 | totma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=totma
# Processing Record 4 of Set 13 | bethanien
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=bethanien
# Processing Record 5 of Set 13 | manicore
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=manicore
# Processing Record 6 of Set 13 | rustenburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=rustenburg
# Processing Record 7 of Set 13 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=kavaratti
# Processing Record 8 of Set 13 | tomatlan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=tomatlan
# Processing Record 9 of Set 13 | ornskoldsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=ornskoldsvik
# Processing Record 10 of Set 13 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=guerrero%20negro
# Processing Record 11 of Set 13 | luban
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=luban
# Processing Record 12 of Set 13 | gao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=gao
# Processing Record 13 of Set 13 | sabalgarh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=sabalgarh
# Processing Record 14 of Set 13 | hanmer springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=hanmer%20springs
# Processing Record 15 of Set 13 | khorixas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=khorixas
# Processing Record 16 of Set 13 | college
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=college
# Processing Record 17 of Set 13 | glotovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=glotovka
# Processing Record 18 of Set 13 | kramat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=kramat
# Processing Record 19 of Set 13 | uusikaupunki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=uusikaupunki
# Processing Record 20 of Set 13 | melenki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=melenki
# Processing Record 21 of Set 13 | nicolas bravo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=nicolas%20bravo
# Processing Record 22 of Set 13 | sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=sisimiut
# Processing Record 23 of Set 13 | roseland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=roseland
# Processing Record 24 of Set 13 | kachug
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=61865aa8640807626e4e6c13a681b72d&q=kachug
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert array of JSONs into Pandas DataFrame
city_data_pd = pd.DataFrame(city_data)

# Extract relevant fields from the data frame
lats = city_data_pd["Lat"]
max_temps = city_data_pd["Max Temp"]
humidity = city_data_pd["Humidity"]
cloudiness = city_data_pd["Cloudiness"]
wind_speed = city_data_pd["Wind Speed"]

# Export the City_Data into a csv
city_data_pd.to_csv(output_data_file, index_label="City_ID")

# Show Record Count
city_data_pd.count()
# Out:
# City          554
# Cloudiness    554
# Country       554
# Date          554
# Humidity      554
# Lat           554
# Lng           554
# Max Temp      554
# Wind Speed    554
# dtype: int64

# %%
# Display the City Data Frame
city_data_pd.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0         aswan           0      EG  1536566400        28  24.09   32.90
# 1  punta arenas           0      CL  1536566400        86 -53.16  -70.91
# 2       mataura           0      NZ  1536570313        95 -46.19  168.86
# 3    georgetown          20      GY  1536566400       100   6.80  -58.16
# 4        hobart           0      AU  1536568200        76 -42.88  147.33
#
#    Max Temp  Wind Speed
# 0     93.20       12.75
# 1     39.20        8.05
# 2     40.18        5.17
# 3     73.40        2.24
# 4     55.40        4.70

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build scatter plot for latitude vs temperature
plt.scatter(lats, 
            max_temps,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build the scatter plots for each city types
plt.scatter(lats, 
            humidity,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build the scatter plots for each city types
plt.scatter(lats, 
            cloudiness,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for each city types
plt.scatter(lats, 
            wind_speed,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()
